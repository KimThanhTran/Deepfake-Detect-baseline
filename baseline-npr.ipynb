# %%
# %cd /kaggle/working
# !rm -rf /kaggle/working/Deepfake-Detect-baseline-main /kaggle/working/repo.zip
# !wget -O repo.zip https://github.com/KimThanhTran/Deepfake-Detect-baseline/archive/refs/heads/main.zip
# !unzip -q repo.zip
# !ls /kaggle/working

# %%
# %cd /kaggle/working/Deepfake-Detect-baseline-main
# !pip install -r requirements.txt

# %%
import torch

print('cuda_available =', torch.cuda.is_available())
print('device =', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'No GPU')

# %%
# !find /kaggle/input/datasets/kimthanhtrn/deepfake-benchmark-zips/ForenSynths/ForenSynths -maxdepth 2 -type d | sort

# %%
# %cd /kaggle/working/Deepfake-Detect-baseline-main
# !python train.py --model_type baseline --name paper_baseline_10ep --dataroot /kaggle/input/datasets/kimthanhtrn/deepfake-benchmark-zips/ForenSynths/ForenSynths --niter 10 --gpu_ids 0 --num_threads 4

# %%
# %cd /kaggle/working/Deepfake-Detect-baseline-main
# !zip -r /kaggle/working/paper_baseline_10ep_ckpt.zip ./checkpoints/paper_baseline_10ep*
