# %% [markdown]
# # Hybrid Spatial-Frequency on Kaggle
#
# Notebook chạy mô hình hybrid trên cùng ForenSynths để so sánh công bằng với baseline.

# %%
# %cd /kaggle/working
# !rm -rf /kaggle/working/Deepfake-Detect-baseline-main /kaggle/working/repo.zip
# !wget -O repo.zip https://github.com/KimThanhTran/Deepfake-Detect-baseline/archive/refs/heads/main.zip
# !unzip -q repo.zip
# !ls /kaggle/working

# %%
# %cd /kaggle/working/Deepfake-Detect-baseline-main
# !pip install -r requirements.txt

# %%
import torch

print('cuda_available =', torch.cuda.is_available())
print('device =', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'No GPU')

# %%
# %cd /kaggle/working/Deepfake-Detect-baseline-main
# !python train.py --model_type hybrid --name paper_hybrid_10ep --no_timestamp --dataroot /kaggle/input/datasets/kimthanhtrn/deepfake-benchmark-zips/ForenSynths/ForenSynths --niter 10 --gpu_ids 0 --num_threads 4 --batch_size 16

# %%
# %cd /kaggle/working/Deepfake-Detect-baseline-main
# !zip -r /kaggle/working/paper_hybrid_10ep_ckpt.zip ./checkpoints/paper_hybrid_10ep
